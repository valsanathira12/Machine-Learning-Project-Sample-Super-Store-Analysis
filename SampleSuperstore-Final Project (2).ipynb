# %% [markdown]
# #  [Sample Super Store Analysis using Machine Learning Algorithms ](#division_ID)

# %% [markdown]
# ![1624976.jpg](attachment:1624976.jpg)
#
#
# The sample Dataset includes data for the Sales of multiple products sold by a company along with subsequent information related to geography, Product categories, and subcategories, sales, and profits, segmentation among the consumers, etc.Here we are trying to perform extensive data analysis to deliver insights on how the company can increase its profits while minimizing the losses and also understanding which products, regions, categories and customer segments they should target or avoid.Our task is to analyse the sales data and identify weak areas and opportunities for Super Store to boost business growth.

# %% [markdown]
# #### Source of Dataset:
# https://www.kaggle.com/datasets/vivek468/superstore-dataset-final

# %% [markdown]
# #### Dataset Features:
#
#     • Row ID - Unique ID for each row.
# 	• Order ID - Unique Order ID for each Customer.
# 	• Order Date - Order Date of the product.
# 	• Ship Date - Shipping Date of the Product.
# 	• Ship Mode - Shipping Mode specified by the Customer.
# 	• Customer ID - Unique ID to identify each Customer.
# 	• Customer Name - Name of the Customer.
# 	• Segment - The segment where the Customer belongs.
# 	• Country - Country of residence of the Customer.
# 	• City - City of residence of of the Customer.
# 	• State - State of residence of the Customer.
# 	• Postal Code - Postal Code of every Customer.
# 	• Region - Region where the Customer belong.
# 	• Product ID - Unique ID of the Product.
# 	• Category - Category of the product ordered.
# 	• Sub-Category - Sub-Category of the product ordered.
# 	• Product Name - Name of the Product
# 	• Sales - Sales of the Product.
# 	• Quantity - Quantity of the Product.
# 	• Discount - Discount provided.
#     • Profit - Profit/Loss incurred.

# %% [markdown]
# #### Problem Statement:
#  Analyzing this data to extract crucial information and to become an important part of the decision-making process.Our task is to analyse the sales data and identify weak areas and opportunities for Super Store to boost business growth.
# 1. Which state yields the highest profit and highest sales?
# 2. Which Sub Category yields the highest profit and highest sales?
# 3. Name of the customers providing highest sales and profit?
# 4. Most preferred Shipping Mode, and its relationship with sales and profit?
# 5. Identifying the segment which contributes to sales and yields higher profit?
# 6. Which region generates the most sales?
# 7. Identify the city contributing the to sales and profit?
# 8. Which category of products generates the highest revenue and profit?
# 9. What are the top selling products in the superstore?
# 10. Most commonly given discount %?
# 11. What is the profit trend over time (monthly, yearly)?
# 12. Does delivery time affect sales and profit?

# %% [markdown]
# #### Loading Libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Reading the dataset

# %%
df=pd.read_csv("SampleSuperstore.csv")

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %% [markdown]
# #### Checking the Data Attributes:

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %% [markdown]
# #### As we can see there are 3 datatypes:
#
# - object: data is in categorical format like Order ID,Product Name, State, etc.
# - int64: data is in numerical format like Postal code, Quantity, row ID.
# - float64: data is in decimal format like Sales, Discount, Profit.

# %% [markdown]
# #### Preparing data:

# %% [markdown]
# - We can see that Ship Date and Order Date are in object format so we have to convert it into datetime format.

# %%
df['Ship Date']=pd.to_datetime(df['Ship Date'],format='%m/%d/%Y')
df['Ship Date'].head()
# Out:
# 0   2016-11-11
# 1   2016-11-11
# 2   2016-06-16
# 3   2015-10-18
# 4   2015-10-18
# Name: Ship Date, dtype: datetime64[ns]

# %%
df['Order Date']=pd.to_datetime(df['Order Date'],format='%m/%d/%Y')
df['Order Date'].head()
# Out:
# 0   2016-11-08
# 1   2016-11-08
# 2   2016-06-12
# 3   2015-10-11
# 4   2015-10-11
# Name: Order Date, dtype: datetime64[ns]

# %%
df['OrderY']=df['Order Date'].dt.year
df['OrderM']=df['Order Date'].dt.month
df['OrderD']=df['Order Date'].dt.day

# %% [markdown]
# #### Handling Missing Values:

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# OrderY           0
# OrderM           0
# OrderD           0
# dtype: int64

# %% [markdown]
#  As we can see there is no null entry which is good for us.

# %% [markdown]
# ### [Exploratory Data Analysis:](#division_ID)

# %% [markdown]
# ### Which country do they have sales in ?

# %%
df['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
f1={"Family":"Arial","color":"black","size":16}
sns.set_theme()

# %% [markdown]
# #### Observation: All the sales are happening in the United States Of America.

# %% [markdown]
# ### Top 20 states having highest sales

# %%
df.groupby('State')['Sales'].sum().sort_values(ascending=False).head(20).plot.bar(color="g")
plt.xlabel("State",fontdict=f1)
plt.ylabel("Sales",fontdict=f1)
plt.title("Top 20 States by sales",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: The above bar graph shows the list of top 20 states having the highest sales.First is "California",followed by "New York" and then"Texas" holding the first three positions.

# %% [markdown]
# ### Top 20 states by Profit

# %%
df.groupby('State')['Profit'].sum().sort_values(ascending=False).head(20).plot.bar(color="g")
plt.xlabel("State",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("Top 20 States by Profit",fontdict=f1)
plt.show()
plt.show()

# %% [markdown]
# #### Observation:The above bar graph shows the list of top 20 states giving the highest profit. New York and California provide the highest profit amoung all the states.

# %% [markdown]
# ### Let us analyse the  Sub Categories by Sales

# %%
df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False).plot.bar(color="y" )
plt.xlabel("Sub-Category",fontdict=f1)
plt.ylabel("Sales",fontdict=f1)
plt.title("Sub Category by Sales",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation:The above bar graph shows the list of top 20 sub-categories by sales. Phones and chairs are the highest selling product.

# %% [markdown]
# ### Let us analyse the Sub Categories by Profit

# %%
df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False).plot.bar(color="y" )
plt.xlabel("Sub-Category",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("Sub Category by Profit",fontdict=f1)
plt.show()

# %% [markdown]
#  #### Observation:From the above bar graph we can conclude that, the products having the highest profits are Copies,Phones and Accessories.Where as Supplies, Bookcases and Tables are being sold at a loss.

# %% [markdown]
# ### Let us analyse the top 20 customers by sales

# %%
df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(20).plot.bar(color="orange")
plt.xlabel("Customer Name",fontdict=f1)
plt.ylabel("Sales",fontdict=f1)
plt.title("Customer Name by Sales",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation:From the above bar graph we can find the top 20 customers against sales. Mr.Sean Miller provides the highest sales.

# %% [markdown]
# ### Let us analyse the top 20 customers by profit

# %%
df.groupby('Customer Name')['Profit'].sum().sort_values(ascending=False).head(20).plot.bar(color="orange")
plt.xlabel("Customer Name",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("Customer Name by Sales",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation:From the above bar graph we can find the top 20 customers w.r.t profit. Deals made by Ms.Tamara Chand has yield the higest profit

# %% [markdown]
# ### Let us analyse which is the most preferred shipping mode

# %%
df['Ship Mode'].value_counts().plot.bar(color="green")
plt.xlabel("Shipping Mode",fontdict=f1)
plt.ylabel("Rate",fontdict=f1)
plt.title("Most preferred Shipping mode",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation:From the above bar graph we can  conclude that customers prefer "standard class ship mode" the most.

# %% [markdown]
# ### Analysing the relationship between shipping mode and sales

# %%
df.groupby('Ship Mode')['Sales'].sum().sort_values(ascending=False).plot.bar(color="orange")
plt.xlabel("Ship Mode",fontdict=f1)
plt.ylabel("Sales",fontdict=f1)
plt.title("Ship Mode by Sales",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation:From the above bar graph we can  conclude that most sales prefer standard shipping mode.

# %% [markdown]
# ### Analysing the relationship between shipping mode and profit

# %%
df.groupby('Ship Mode')['Profit'].sum().sort_values(ascending=False).plot.bar(color="orange")
plt.xlabel("Ship Mode",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("Ship Mode by Profit",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation:From the above bar graph we can conclude that sales providing the highest profit prefer "standard class ship mode".

# %% [markdown]
# ### Let us analyse the contribution of the various segments

# %%
df['Segment'].value_counts().plot.pie(autopct='%1.2f%%')
plt.title("Segement",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation:From the above Pie chart we can conclude that more than half customer belong to the  Consumer Segment.

# %% [markdown]
# ### Let us analyse the segment vise profit

# %%
df.groupby('Segment')['Profit'].sum().sort_values(ascending=False).plot.bar(color="green")
plt.xlabel("Segment",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("Segment by Profit",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation:From the above bar graph we can conclude that sales in the consumer segment provide highest profit.

# %% [markdown]
# ### Let us analyse the segment vise sales

# %%
df.groupby('Segment')['Sales'].sum().sort_values(ascending=False).plot.bar(color="green")
plt.xlabel("Segment",fontdict=f1)
plt.ylabel("Sales",fontdict=f1)
plt.title("Segment by Sales",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation:From the above bar graph we can conclude that highest sales happen in the Consumer segment.

# %% [markdown]
# ### Let us analyse the top 10 cities

# %%
df['City'].value_counts().head(10).plot.bar(color="green")
plt.show()

# %% [markdown]
# #### Observation: Above bar graph represent top 10 cities present in the data and as we can see New York City has most orders placed followed by Los Angles, Philadelphia, etc.

# %% [markdown]
# ### Let us analyse the cities with respect to sales.

# %%
df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(20).plot.bar(color="green")
plt.xlabel("City",fontdict=f1)
plt.ylabel("Sales",fontdict=f1)
plt.title("City by Sales",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: Above bar graph represent top 20 cities by sales .New York City leading the list.

# %% [markdown]
# ### Lets analyse the cities with respect to profit.

# %%
df.groupby('City')['Profit'].sum().sort_values(ascending=False).head(20).plot.bar(color="green")
plt.xlabel("City",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("City by Profit",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: Above bar graph represent top 20 cities by profit .New York City providing the highest profit.

# %% [markdown]
# ### Let us analyse the contribution of various regions

# %%
df['Region'].value_counts(normalize=True).plot.pie(autopct='%1.1f%%')
plt.show()

# %% [markdown]
# #### Observation: From the above pie chart we can conclude that most of the sales happen in West side of country followed by East, Central and South.

# %% [markdown]
# ### Let us analyse the region wise profit

# %%
df.groupby('Region')['Profit'].sum().sort_values(ascending=False).head(20).plot.bar(color="green")
plt.xlabel("Region",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("Region by profit",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: The above bar grap shows that the central region yeild the highest profit, followed by east, west and south.

# %% [markdown]
# ### Let us analyse the region wise sales

# %%
df.groupby('Region')['Sales'].sum().sort_values(ascending=False).head(20).plot.bar(color="green")
plt.xlabel("Region",fontdict=f1)
plt.ylabel("Sales",fontdict=f1)
plt.title("Region by sales",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: The above bar grap shows that the highest sales happen in the west region.

# %% [markdown]
# ### Let us analyse the highest preferred category

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Category'].value_counts().plot.bar(color="yellow")
plt.xlabel("Category",fontdict=f1)
plt.ylabel("Range",fontdict=f1)
plt.title("Highest preferred category",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation:From the above bar chart we find that, their are 3 types of Sales Category in which Office Supplies leads the data. Furniture & Technology are on 2nd & 3rd place respectively.

# %% [markdown]
# ### Lets analyse the category wise sales

# %%
df.groupby('Category')['Sales'].sum().sort_values(ascending=False).plot.bar(color="yellow")
plt.xlabel(" Category",fontdict=f1)
plt.ylabel("Sales",fontdict=f1)
plt.title("Category by sales",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: From the above bar chart we find that the highest sales happen in the category of "Technology"

# %% [markdown]
# ### Let us analyse the category wise profit

# %%
df.groupby('Category')['Profit'].sum().sort_values(ascending=False).plot.bar(color="yellow")
plt.xlabel(" Category",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("Category by Profit",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: From the above bar chart we find that the category yeilding the highest profit is Technology.

# %%
df_category=pd.DataFrame(df.groupby('Category')['Sales'].sum())
df_category['Profit']=pd.DataFrame(df.groupby('Category')['Profit'].sum())
print(df_category)
df_category.plot.scatter(x='Sales',y='Profit',color="r")
plt.xlabel("Sales",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("Category by Profit and Sales",fontdict=f1)
plt.show()
# Out:
#                        Sales       Profit
# Category
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008
# Technology       836154.0330  145454.9481

# %% [markdown]
# #### Observation: From the scatter plot we can conclude that Technology has highest sales and profit

# %% [markdown]
# ###  Let us analyse the most preferred products

# %%
df['Product Name'].value_counts(normalize=True).head(10).plot.bar(color="orange")
plt.xlabel("Product Name",fontdict=f1)
plt.ylabel("Range",fontdict=f1)
plt.title("Range of Product Name",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: From the above bar chart we can conclude that the most commonly prefered products are Staple envelop, easy-staple paper and Staples

# %% [markdown]
# ### Let us analyse the product yielding the highest profit

# %%
df.groupby('Product Name')['Profit'].sum().sort_values(ascending=False).head(10).plot.bar(color="green")
plt.xlabel("Product Name",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("Product Name by Profit",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: From the above bar chart we can conclude that the most profitable product is Canon imageCLASS 2200 Advanced Copier

# %% [markdown]
# ### Let us analyse the name of the highly sold product

# %%
df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10).plot.bar(color="green")
plt.xlabel("Product Name",fontdict=f1)
plt.ylabel("Sales",fontdict=f1)
plt.title("Product Name by Sales",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: From the above bar chart we can conclude that the most sold product is Canon imageCLASS 2200 Advanced Copier

# %% [markdown]
# ### Let us analyse the Discount variable

# %%
df['Discount'].value_counts().plot.bar(color="orange")
plt.xlabel("Discount",fontdict=f1)
plt.ylabel("Count",fontdict=f1)
plt.title("Discount ",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation:From the above bar graph we can conclude that mostly discount is provided between 0% to 20%.

# %% [markdown]
# ### Let us analyse the quantity variable

# %%
df['Quantity'].value_counts().plot.bar(color="orange")
plt.xlabel("Quantity",fontdict=f1)
plt.ylabel("Count",fontdict=f1)
plt.title("Mostly ordered ",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation:From the above chart we can say that mostly the order quantity is between 2 and 3.

# %% [markdown]
# ##  Time Series Analysis

# %% [markdown]
# ### Let us visualize the range of Order date

# %%
df['Order Date'].value_counts().plot.line(figsize=(20,10),color="orange")
plt.xlabel("Order Date",fontdict=f1)
plt.ylabel("Range",fontdict=f1)
plt.title("Order Date range",fontdict=f1)
plt.show()

# %% [markdown]
# ### Let us visualize the range of Shipping date

# %%
df['Ship Date'].value_counts().plot.line(figsize=(16,6),color="orange")
plt.xlabel("Ship Date",fontdict=f1)
plt.ylabel("Range",fontdict=f1)
plt.title("Shipping Date range",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation :From the above graphs we can see that Order Date and Ship Date values cover vast range.

# %% [markdown]
# ### Let us analyse the sales per year

# %%
df.groupby('OrderY')['Sales'].sum().plot.bar(color="yellow")
plt.xlabel("Year",fontdict=f1)
plt.ylabel("Sales",fontdict=f1)
plt.title("Sales per year",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: From the above graph we can conclude that sales is increasing year by year.

# %% [markdown]
# ### Let us analyse the profit over years

# %%
df.groupby('OrderY')['Profit'].sum().plot.bar(color="yellow")
plt.xlabel("Year",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("Profit per year",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: Sales and Profit has been growing year by year.

# %% [markdown]
# ### Let us analyse the months having the highest sales

# %%
df.groupby('OrderM')['Sales'].sum().plot.bar(color="orange")
plt.xlabel("Year",fontdict=f1)
plt.ylabel("Sales",fontdict=f1)
plt.title("Sales per Month",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: Highest sales happen in the months 11,12 and 9

# %% [markdown]
# ### Let us analyse the month having the highest profit

# %%
df.groupby('OrderM')['Profit'].sum().plot.bar(color="orange")
plt.xlabel("Year",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("Profit per Month",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: We can concluse that most profitable sales happen in the month of December

# %% [markdown]
# ### Let us analyse the sales over the years

# %%
plt.figure(figsize=(20,5))
df.groupby(['OrderY','OrderM'])['Sales'].sum().plot(color="green")
plt.xlabel("Year",fontdict=f1)
plt.ylabel("Sales",fontdict=f1)
plt.title("Yearly Sales",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: Sales Order is increasing yearly.

# %% [markdown]
# ### Let us analyse the profit over the years

# %%
plt.figure(figsize=(20,5))
df.groupby(['OrderY','OrderM'])['Profit'].sum().plot(color="green")
plt.xlabel("Year",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("Yearly profit",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation: Yearly profit is increasing.

# %% [markdown]
# ### Let us analyse if the delivery time is affecting the profit

# %%
df["deliverytime"]=df["Ship Date"]-df["Order Date"]

# %%
df.groupby('deliverytime')['Profit'].sum().plot.bar(color="orange")
plt.xlabel("Delivery time",fontdict=f1)
plt.ylabel("Profit",fontdict=f1)
plt.title("Delivery time v/s profit",fontdict=f1)
plt.show()

# %% [markdown]
# #### Observation:Delivery time of 4 days have the higest profit.

# %% [markdown]
# ### Let us analyse the numerical data using a heatmap-Sales,Quantity,Discount & Profit

# %%
num_df=df[['Sales','Quantity','Discount','Profit']]
sns.heatmap(num_df.corr(), annot=True)
plt.show()

# %% [markdown]
# #### Observation: We can conclude the heatmap that their is no strong corelation between the numerical variables

# %% [markdown]
# ### Data Preprocessing

# %%
# Lets drop the unwanted columns
df.drop(['OrderM', 'OrderY', 'OrderD'],axis=1,inplace=True)

# %% [markdown]
# #### Lets change the Profit column-Target Variable, of the dataset into three catorgorical values: Profit=1, Loss=0,Nill =2.

# %%
def typ(x):
    if x<0.00:
        x=1
    elif x>0.00:
        x=0
    else:
        x=2
    return x

# %%
df['Profit']=df['Profit'].apply(lambda x: typ(x))
df['Profit'].value_counts()
# Out:
# 0    8058
# 1    1871
# 2      65
# Name: Profit, dtype: int64

# %%
x=df.drop("Profit",axis=1)
y=df['Profit']

# %%
# Lets use the Label Encoder to convert all the catogerical values to numerical values before applying the ML Algorithms

# %%
from sklearn.preprocessing import LabelEncoder

# %%
x_enc=x.copy()
for i in x.columns:
    le = LabelEncoder()
    x_enc[i]=le.fit_transform(x[i].values)

# %%
x_enc.head()
# Out:
#    Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0       0      2500         864        929          2          143
# 1       1      2500         864        929          2          143
# 2       2      2296         732        787          2          237
# 3       3      4372         519        568          3          705
# 4       4      4372         519        568          3          705
#
#    Customer Name  Segment  Country  City  ...  Postal Code  Region  \
# 0            166        0        0   194  ...          217       2
# 1            166        0        0   194  ...          217       2
# 2            201        1        0   266  ...          517       3
# 3            687        0        0   153  ...          170       2
# 4            687        0        0   153  ...          170       2
#
#    Product ID  Category  Sub-Category  Product Name  Sales  Quantity  \
# 0          12         0             4           386   4205         1
# 1          55         0             5           839   5219         2
# 2         946         1            10          1433    969         1
# 3         319         0            16           366   5392         4
# 4        1316         1            14           573   1360         1
#
#    Discount  deliverytime
# 0         0             3
# 1         0             3
# 2         0             4
# 3         7             7
# 4         3             7
#
# [5 rows x 21 columns]

# %%
#Lets split our data set into train and test part using train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_enc,y, test_size=0.3)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_dt=DecisionTreeClassifier(criterion='gini', max_depth=9)
model_dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=9)

# %%
model_dt.score(x_train,y_train)*100 # Score of train data is 97.6%
# Out:
# 97.56969263759828

# %%
model_dt.score(x_test, y_test)*100 #Score of test data is 95.2%
# Out:
# 95.0650216738913

# %%
y_pred1=model_dt.predict(x_test)#y_predict

# %%
df_new_dt=pd.DataFrame({"Actual":y_test,"Predict":y_pred1})# lets create a dataframe of actual and predicted
df_new_dt
# Out:
#       Actual  Predict
# 5746       0        0
# 2960       0        0
# 8090       0        0
# 2984       1        1
# 3101       0        0
# ...      ...      ...
# 1699       0        0
# 3194       0        0
# 6134       0        0
# 5592       0        0
# 5219       0        0
#
# [2999 rows x 2 columns]

# %%
# accuracy score
from sklearn.metrics import accuracy_score

# %%
score_dt=accuracy_score(y_test, y_pred1)*100
score_dt
# Out:
# 95.0650216738913

# %%
# confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred1)
# Out:
# array([[2385,   35,    8],
#        [  85,  463,    3],
#        [  11,    6,    3]], dtype=int64)

# %%
#plot_confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %%
sns.set_theme(style="white", palette=None)
plot_confusion_matrix(model_dt,x_test,y_test)
plt.show()

# %%
report_dt =classification_report(y_test,y_pred1)
print(report_dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      2428
#            1       0.92      0.84      0.88       551
#            2       0.21      0.15      0.18        20
#
#     accuracy                           0.95      2999
#    macro avg       0.70      0.66      0.68      2999
# weighted avg       0.95      0.95      0.95      2999

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf=RandomForestClassifier(n_estimators=100)

# %%
model_rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
model_rf.score(x_train,y_train)*100 # training data score
# Out:
# 100.0

# %%
model_rf.score(x_test,y_test)*100 # test data score
# Out:
# 95.16505501833944

# %%
y_pred2=model_rf.predict(x_test)
y_pred2
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
df_new_rf=pd.DataFrame({"Actual":y_test,"Predict":y_pred2})# lets create a dataframe of actual and predicted
df_new_rf
# Out:
#       Actual  Predict
# 5746       0        0
# 2960       0        0
# 8090       0        0
# 2984       1        1
# 3101       0        0
# ...      ...      ...
# 1699       0        0
# 3194       0        0
# 6134       0        0
# 5592       0        0
# 5219       0        0
#
# [2999 rows x 2 columns]

# %%
score_rf=accuracy_score(y_test, y_pred2)*100
score_rf
# Out:
# 95.16505501833944

# %%
# confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred2)
# Out:
# array([[2413,   15,    0],
#        [ 110,  441,    0],
#        [  16,    4,    0]], dtype=int64)

# %%
#plot_confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %%
plot_confusion_matrix(model_rf,x_test,y_test)
plt.show()

# %%
#classification_report
from sklearn.metrics import classification_report

# %%
report_rf =classification_report(y_test,y_pred2)
print(report_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      2428
#            1       0.96      0.80      0.87       551
#            2       0.00      0.00      0.00        20
#
#     accuracy                           0.95      2999
#    macro avg       0.64      0.60      0.61      2999
# weighted avg       0.95      0.95      0.95      2999

# %% [markdown]
# ## Naive Bayes- GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model_nb=GaussianNB()

# %%
model_nb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
model_nb.score(x_train, y_train) #train dataset score
# Out:
# 0.9355253752680486

# %%
model_nb.score(x_test, y_test) # test dataset score
# Out:
# 0.9416472157385796

# %%
y_pred3=model_nb.predict(x_test)
y_pred3
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
df_new_nb=pd.DataFrame({"Actual":y_test,"Predict":y_pred3})# lets create a dataframe of actual and predicted
df_new_nb
# Out:
#       Actual  Predict
# 5746       0        0
# 2960       0        0
# 8090       0        0
# 2984       1        1
# 3101       0        0
# ...      ...      ...
# 1699       0        0
# 3194       0        0
# 6134       0        0
# 5592       0        0
# 5219       0        0
#
# [2999 rows x 2 columns]

# %%
score_nb=accuracy_score(y_test, y_pred3)*100 # accuracy_score
score_nb
# Out:
# 94.16472157385796

# %%
confusion_matrix(y_test,y_pred3)#confusion_matrix
# Out:
# array([[2418,   10,    0],
#        [ 145,  406,    0],
#        [  18,    2,    0]], dtype=int64)

# %%
plot_confusion_matrix(model_nb,x_test,y_test)#plot confusion matrix
plt.show()

# %%
report_nb =classification_report(y_test,y_pred3)# Classification report
print(report_nb)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      2428
#            1       0.97      0.74      0.84       551
#            2       0.00      0.00      0.00        20
#
#     accuracy                           0.94      2999
#    macro avg       0.64      0.58      0.60      2999
# weighted avg       0.94      0.94      0.94      2999

# %% [markdown]
# ## K Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn=KNeighborsClassifier(n_neighbors=21)

# %%
model_knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=21)

# %%
model_knn.score(x_train,y_train)*100
# Out:
# 81.98713366690494

# %%
model_knn.score(x_test,y_test)*100
# Out:
# 81.36045348449483

# %%
y_pred4=model_knn.predict(x_test)
y_pred4
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
df_new_rf=pd.DataFrame({"Actual":y_test,"Predict":y_pred4})# lets create a dataframe of actual and predicted
df_new_rf
# Out:
#       Actual  Predict
# 5746       0        0
# 2960       0        0
# 8090       0        0
# 2984       1        1
# 3101       0        0
# ...      ...      ...
# 1699       0        0
# 3194       0        0
# 6134       0        0
# 5592       0        0
# 5219       0        0
#
# [2999 rows x 2 columns]

# %%
score_kn=accuracy_score(y_test, y_pred4)*100 # accuracy_score
score_kn
# Out:
# 81.36045348449483

# %%
confusion_matrix(y_test,y_pred4)#confusion_matrix
# Out:
# array([[2384,   44,    0],
#        [ 495,   56,    0],
#        [  17,    3,    0]], dtype=int64)

# %%
plot_confusion_matrix(model_knn,x_test,y_test)#plot confusion matrix
plt.show()

# %%
report_knn =classification_report(y_test,y_pred4)# Classification report
print(report_knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.98      0.90      2428
#            1       0.54      0.10      0.17       551
#            2       0.00      0.00      0.00        20
#
#     accuracy                           0.81      2999
#    macro avg       0.46      0.36      0.36      2999
# weighted avg       0.77      0.81      0.76      2999

# %% [markdown]
# ### Conclusion:

# %% [markdown]
# ### Finding the best method:

# %%
results=pd.DataFrame({'Model':['Decision Tree','Random Forest','Gaussian NB','KNN'],'Score':[score_dt,score_rf,score_nb,score_kn]})
result_df=results.sort_values(by='Score',ascending=False)
result_df=result_df.reset_index(drop=True)
result_df.head()
# Out:
#            Model      Score
# 0  Random Forest  95.165055
# 1  Decision Tree  95.065022
# 2    Gaussian NB  94.164722
# 3            KNN  81.360453

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Model',y='Score',data=result_df)
plt.show()

# %% [markdown]
# #### Accuracy Score of various ML models:
#     Decision Tree - 95.165%
#     Random Forest- 95.065%
#     GaussianNB - 94.16%
#     KNN-81.36%
#
#  #### Hence, we can conclude that Decision Tree and Random Forest algorithm has the highest Accuarcy Score and is the best suitable ML algorithm for this dataset.
